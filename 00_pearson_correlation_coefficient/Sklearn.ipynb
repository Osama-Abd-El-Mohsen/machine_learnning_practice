# %%
import pandas as pd
import math
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../data_sets/Salary_Data.csv')

# %%
data.head()
data.shape
print("="*50)
print(data.describe())
print("="*50)
print(data.info())
print("="*50)
# Out:
# ...
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes
# None
# ...

# %%
sns.pairplot(data=data)
plt.show()

# %%
x = data.iloc[:,:-1]
y = data.iloc[:,1]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=10,train_size=0.8)

my_module = LinearRegression()
my_module.fit(x_train,y_train)
y_predict = my_module.predict(x_test)
my_module.score(x_train,y_train)
my_module.score(x_test,y_test)

plt.scatter(x_train,y_train,c='r')
plt.plot(x_train,my_module.predict(x_train))
plt.title("Trained data Vs predict Salary ")
plt.show()

# %%
plt.scatter(x_test,y_test,c='r')
plt.plot(x_test,y_predict)
plt.title("Test data Vs predict Salary ")
plt.show()

# %%
plt.plot(y_test.values)
plt.plot(y_predict)
plt.title("Predict and actual data")
plt.show()

# %%
plt.plot(abs(y_test.values - y_predict))
plt.title("Error bettween Predict and actual data")
plt.show()

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 9785570.138914317

# %%
r2_score(y_test,y_predict)
# Out:
# 0.9816423482070253

# %%
print(f"coefficient  = {my_module.coef_}")
print(f"intercept  = {my_module.intercept_}")
# Out:
# coefficient  = [9356.86299354]
# intercept  = 26089.096632416724
